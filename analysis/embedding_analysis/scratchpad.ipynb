# %%
import torch
import numpy as np
import pandas as pd

# %%
embedding_path = "/home/zachkaras/fmri/fmri_model_data/model_embeddings/code/codegemma_2b_question_0.pt"
test = torch.load(embedding_path)
