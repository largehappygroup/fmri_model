# %%
import cortex

# %%
# cortex.utils.download_subject(subject_id='fsaverage')

# %%
ref = "/home/zachkaras/atlases/MNI152_T1_2mm_brain.nii.gz"
# cortex.align.automatic(subject='sub-111', xfmname='plots', reference=ref)
cortex.align.automatic_fsl(subject='fsaverage', xfmname='mni2py', reference=ref)
# Out:
# Running freesurfer BBR
# /home/zachkaras/miniconda3/envs/cortex/lib/python3.14/site-packages/cortex/align.py:413: UserWarning: Defaults changed in pycortex 1.2.8. Now automatic alignment uses Freesurfer's bbregister and mri_coreg for initialization. If you want to use FSL's BBR, use the function `cortex.align.automatic_fsl` instead.
#   warnings.warn(
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 3
#       1 ref = "/home/zachkaras/atlases/MNI152_T1_2mm_brain.nii.gz"
#       2 # cortex.align.automatic(subject='sub-111', xfmname='plots', reference=ref)
# ----> 3 cortex.align.automatic(subject='fsaverage', xfmname='mni2py', reference=ref)
#
# File ~/miniconda3/envs/cortex/lib/python3.14/site-packages/cortex/align.py:439, in automatic(subject, xfmname, reference, init, epi_mask, intermediate, reference_contrast, noclean)
#     436     cmd += f" --int {intermediate}"
#     437 cmd = cmd.format(sub=subject, absref=reference, cache=cache)
# --> 439 if sp.call(cmd.split()) != 0:
#     440     raise IOError("Error calling freesurfer BBR!")
#     442 xfm = Transform.from_freesurfer(
#     443     os.path.join(cache, "register.dat"), reference, subject
#     444 )
#
# File ~/miniconda3/envs/cortex/lib/python3.14/subprocess.py:396, in call(timeout, *popenargs, **kwargs)
#     388 def call(*popenargs, timeout=None, **kwargs):
#     389     """Run command with arguments.  Wait for command to complete or
#     390     for timeout seconds, then return the returncode attribute.
#     391
#    (...)    394     retcode = call(["ls", "-l"])
#     395     """
# --> 396     with Popen(*popenargs, **kwargs) as p:
#     397         try:
#     398             return p.wait(timeout=timeout)
#
# File ~/miniconda3/envs/cortex/lib/python3.14/subprocess.py:1039, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1035         if self.text_mode:
#    1036             self.stderr = io.TextIOWrapper(self.stderr,
#    1037                     encoding=encoding, errors=errors)
# -> 1039     self._execute_child(args, executable, preexec_fn, close_fds,
#    1040                         pass_fds, cwd, env,
#    1041                         startupinfo, creationflags, shell,
#    1042                         p2cread, p2cwrite,
#    1043                         c2pread, c2pwrite,
#    1044                         errread, errwrite,
#    1045                         restore_signals,
#    1046                         gid, gids, uid, umask,
#    1047                         start_new_session, process_group)
#    1048 except:
#    1049     # Cleanup if the child failed starting.
#    1050     for f in filter(None, (self.stdin, self.stdout, self.stderr)):
#
# File ~/miniconda3/envs/cortex/lib/python3.14/subprocess.py:1990, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session, process_group)
#    1988     err_msg = os.strerror(errno_num)
#    1989 if err_filename is not None:
# -> 1990     raise child_exception_type(errno_num, err_msg, err_filename)
#    1991 else:
#    1992     raise child_exception_type(errno_num, err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'bbregister'

# %%
import os
